# %% [markdown]
# The assignment is about working with web APIs. First, I find an API in Movie Reviews in NYT Developers, then acquire an API-key to access the data. I set the parameter as part-time for the reviewers, and use the generated API address to connect the data to Python. After that, I transfer data from dict to data frames to prepare for data analysis.
# Next part, I use the Movie Reviewers data, but set the parameter as full-time for the reviewers, to work out again.

# %% [markdown]
# Part 1. Part-time reviewer data

# %%
import requests
import json

# import json_normalize
from pandas.io.json import json_normalize

url = 'https://api.nytimes.com/svc/movies/v2/critics/part-time.json?api-key=AzC48guEeGWIThFQPgPVVX0mFxlA9U1t'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
# now convert the 'resp' object's JSON content into a list of native Python objects
data = resp.json()
type(data)
# Out:
# dict

# %%
# how many items are in the list object?
len(data)
# Out:
# 4

# %%
# check the content of the list
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'num_results': 56,
#  'results': [{'display_name': 'A. H. Weiler',
#    'sort_name': 'Weiler, A. H.',
#    'status': 'part-time',
#    'bio': '',
#    'seo_name': 'A-H-Weiler',
#    'multimedia': None},
#   {'display_name': 'Andre Sennwald',
#    'sort_name': 'Sennwald, Andre',
#    'status': 'part-time',
#    'bio': '',
#    'seo_name': 'Andre-Sennwald',
#    'multimedia': None},
#   {'display_name': 'Andy Webster',
#    'sort_name': 'Webster, Andy',
#    'status': 'part-time',
#    'bio': '',
#    'seo_name': 'Andy-Webster',
#    'multimedia': None},
#   {'display_name': 'Anita Gates',
#    'sort_name': 'Gates, Anita',
#    'status': 'part-time',
#    'bio': '',
#    'seo_name': 'Anita-Gates',
#    'multimedia': None},
#   {'display_name': 'B. R. Crisler',
#    'sort_name': 'Crisler, B. R.',
#    'status': 'part-time',
#    'bio': '',
#    'seo_name': 'B-R-Crisler',
# ...

# %%
# use json_normalize function to transfer valuable data 'results' to dataframe
json_normalize(data['results'])
# Out:
#      bio         display_name multimedia             seo_name  \
# 0                A. H. Weiler       None           A-H-Weiler
# 1              Andre Sennwald       None       Andre-Sennwald
# 2                Andy Webster       None         Andy-Webster
# 3                 Anita Gates       None          Anita-Gates
# 4               B. R. Crisler       None          B-R-Crisler
# 5   None         Ben Brantley       None         Ben-Brantley
# 6   None       Ben Kenigsberg       None       Ben-Kenigsberg
# 7             Bosley Crowther       None      Bosley-Crowther
# 8   None       Carina Chocano       None       Carina-Chocano
# 9                 Caryn James       None          Caryn-James
# 10          D. J. R. Bruckner       None       D-J-R-Bruckner
# 11               Dana Stevens       None         Dana-Stevens
# 12  None       Daniel M. Gold       None        Daniel-M-Gold
# 13                  Dave Kehr       None            Dave-Kehr
# ...

# %% [markdown]
# Part 2. Full-time reviewer data

# %%
url = 'https://api.nytimes.com/svc/movies/v2/critics/full-time.json?api-key=AzC48guEeGWIThFQPgPVVX0mFxlA9U1t'
resp2 = requests.get(url)
resp2
# Out:
# <Response [200]>

# %%
# now convert the 'resp2' object's JSON content into a list of native Python objects
data2 = resp2.json()
type(data2)
# Out:
# dict

# %%
# how many items are in the list object?
len(data2)
# Out:
# 4

# %%
# check the content of the list
data2
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'num_results': 3,
#  'results': [{'display_name': 'A. O. Scott',
#    'sort_name': 'A. O. Scott',
#    'status': 'full-time',
# ...

# %%
# use json_normalize function to transfer valuable data 'results' to dataframe
json_normalize(data2['results'])
# Out:
#                                                  bio    display_name  \
# 0  A. O. Scott joined The New York Times as a fil...     A. O. Scott
# 1  Manohla Dargis is the co-chief film critic for...  Manohla Dargis
# 2  Stephen Holden is a film and music critic for ...  Stephen Holden
#
#    multimedia           multimedia.resource.credit  \
# 0         NaN  Earl Wilson/<br/>The New York Times
# 1         NaN                                  NaN
# 2         NaN         Brent Murray/<br>NYTimes.com
#
#    multimedia.resource.height  \
# 0                       163.0
# 1                         NaN
# 2                       163.0
#
#                              multimedia.resource.src multimedia.resource.type  \
# 0  http://static01.nyt.com/images/2015/10/07/topi...                    image
# 1                                                NaN                      NaN
# 2  http://nytimes.com/images/2007/01/05/movies/sh...                    image
#
# ...
